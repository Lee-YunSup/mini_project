# %% [markdown]
# ## 0. 데이터 불러오기

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('./초등_4학년_수학_차시문항풀이이력.csv', index_col = 0) # index를

# %% [markdown]
# ```python
# print('data 변수 type:',type(data))
# ```

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#                                   사용자ID          차시코드       단원코드    단원제목  \
# 0  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 1  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 2  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 3  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 4  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
#
#               강의내용           강의명  학년  학기  시험구분 강의구분  ...       대단원코드   대단원제목  \
# 0  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 1  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 2  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 3  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 4  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
#
#         중단원코드    중단원제목       소단원코드         소단원제목        토픽코드  \
# ...

# %%
data.tail()
# Out:
#                                       사용자ID          차시코드       단원코드   단원제목  \
# 99995  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB003  T0ME41UAB  2. 각도
# 99996  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB  2. 각도
# 99997  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB  2. 각도
# 99998  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB  2. 각도
# 99999  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB  2. 각도
#
#                강의내용       강의명  학년  학기  시험구분 강의구분  ...       대단원코드  대단원제목  \
# 99995  각의 크기는 얼마일까요  수학 2단원-②   4   1   NaN    E  ...  17120996.0  2. 각도
# 99996   각을 어떻게 그릴까요  수학 2단원-③   4   1   NaN    E  ...  17120996.0  2. 각도
# 99997   각을 어떻게 그릴까요  수학 2단원-③   4   1   NaN    E  ...  17120996.0  2. 각도
# 99998   각을 어떻게 그릴까요  수학 2단원-③   4   1   NaN    E  ...  17120996.0  2. 각도
# 99999   각을 어떻게 그릴까요  수학 2단원-③   4   1   NaN    E  ...  17120996.0  2. 각도
#
#             중단원코드        중단원제목       소단원코드     소단원제목        토픽코드  \
# ...

# %%
# 한번에 헤드와 테일 출력
display(data.head())
display(data.tail())
# Out:
#                                   사용자ID          차시코드       단원코드    단원제목  \
# 0  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 1  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 2  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 3  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 4  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
#
#               강의내용           강의명  학년  학기  시험구분 강의구분  ...       대단원코드   대단원제목  \
# 0  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 1  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 2  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 3  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 4  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
#
#         중단원코드    중단원제목       소단원코드         소단원제목        토픽코드  \
# ...

# %%
display(data.head(3))
display(data.tail(3))
# Out:
#                                   사용자ID          차시코드       단원코드    단원제목  \
# 0  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 1  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 2  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
#
#               강의내용           강의명  학년  학기  시험구분 강의구분  ...       대단원코드   대단원제목  \
# 0  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 1  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 2  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
#
#         중단원코드    중단원제목       소단원코드        소단원제목        토픽코드  \
# 0  14201237.0  다섯 자리 수  12233514.0  다섯 자리 수의 이해  12234054.0
# 1  14201237.0  다섯 자리 수  12233514.0  다섯 자리 수의 이해  12233718.0
# 2  14201237.0  다섯 자리 수  12233514.0  다섯 자리 수의 이해  12234058.0
#
#                                   토픽제목  난이도  평가영역
# 0                           모형 돈 세어 보기  2.0  91.0
# ...

# %%
#pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 30)

data
# Out:
#                                       사용자ID          차시코드       단원코드    단원제목  \
# 0      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 1      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 2      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 3      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 4      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# ...                                     ...           ...        ...     ...
# 99995  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB003  T0ME41UAB   2. 각도
# 99996  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
# 99997  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
# 99998  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
# 99999  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
#
# ...

# %%
data.shape
# Out:
# (100000, 30)

# %%
data.info() # 어떤 컬럼이 있는지 빈값은 없는지 데이터 타입은 어떤지 나옴
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 30 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   사용자ID    100000 non-null  object
#  1   차시코드     100000 non-null  object
#  2   단원코드     100000 non-null  object
#  3   단원제목     100000 non-null  object
#  4   강의내용     100000 non-null  object
#  5   강의명      100000 non-null  object
#  6   학년       100000 non-null  int64
#  7   학기       100000 non-null  int64
#  8   시험구분     0 non-null       float64
#  9   강의구분     99357 non-null   object
#  10  강의타입     100000 non-null  object
#  11  동영상재생시간  100000 non-null  int64
#  12  실제재생시간   100000 non-null  int64
#  13  확인문제점수   100000 non-null  int64
#  14  학습일      100000 non-null  object
#  15  문항번호     92125 non-null   float64
#  16  문항코드     92125 non-null   float64
#  17  사용자입력    92125 non-null   object
#  18  정오답      92125 non-null   object
#  19  영역       92125 non-null   object
# ...

# %%
data.describe()
# Out:
#              학년        학기  시험구분        동영상재생시간         실제재생시간         확인문제점수  \
# count  100000.0  100000.0   0.0  100000.000000  100000.000000  100000.000000
# mean        4.0       1.0   NaN      48.730900     219.806440      10.741930
# std         0.0       0.0   NaN     103.727199    2630.562339      29.028563
# min         4.0       1.0   NaN      -1.000000      -1.000000      -1.000000
# 25%         4.0       1.0   NaN       0.000000      11.000000      -1.000000
# 50%         4.0       1.0   NaN       0.000000      31.000000      -1.000000
# 75%         4.0       1.0   NaN       0.000000     135.000000      -1.000000
# max         4.0       1.0   NaN     758.000000  176513.000000     100.000000
#
#                문항번호          문항코드         대단원코드         중단원코드         소단원코드  \
# count  92125.000000  9.212500e+04  9.212500e+04  9.182100e+04  9.044600e+04
# mean       3.524168  2.990135e+07  1.710045e+07  1.419278e+07  1.223326e+07
# ...

# %%
data[['대단원제목', '중단원제목', '소단원제목', '토픽제목']]
# Out:
#         대단원제목        중단원제목         소단원제목                                 토픽제목
# 0      1. 큰 수      다섯 자리 수   다섯 자리 수의 이해                           모형 돈 세어 보기
# 1      1. 큰 수      다섯 자리 수   다섯 자리 수의 이해                           10000 알아보기
# 2      1. 큰 수      다섯 자리 수   다섯 자리 수의 이해  10000이 ■, 1000이 ▲ ……인 다섯 자리 수를 나타내기
# 3      1. 큰 수      다섯 자리 수  다섯 자리 수의 자릿값                      각 자릿수의 합으로 나타내기
# 4      1. 큰 수      다섯 자리 수  다섯 자리 수의 자릿값                각 자리의 숫자와 나타내는 값 알아보기
# ...       ...          ...           ...                                  ...
# 99995   2. 각도     각의 크기 재기         각도 읽기                      각도기를 사용하여 각을 재기
# 99996   2. 각도  각도기로 각을 그리기         각 그리기           기선 또는 꼭짓점과 각도를 주고 각을 그려 보기
# 99997   2. 각도  각도기로 각을 그리기         각 그리기           기선 또는 꼭짓점과 각도를 주고 각을 그려 보기
# 99998   2. 각도  각도기로 각을 그리기         각 그리기           기선 또는 꼭짓점과 각도를 주고 각을 그려 보기
# 99999   2. 각도  각도기로 각을 그리기      각 그리는 순서                      각도를 그리는 순서 알아보기
#
# [100000 rows x 4 columns]

# %%
data[['대단원제목', '중단원제목', '소단원제목', '토픽제목']].drop_duplicates()
# Out:
#             대단원제목                 중단원제목                         소단원제목  \
# 0          1. 큰 수               다섯 자리 수                   다섯 자리 수의 이해
# 1          1. 큰 수               다섯 자리 수                   다섯 자리 수의 이해
# 2          1. 큰 수               다섯 자리 수                   다섯 자리 수의 이해
# 3          1. 큰 수               다섯 자리 수                  다섯 자리 수의 자릿값
# 4          1. 큰 수               다섯 자리 수                  다섯 자리 수의 자릿값
# ...           ...                   ...                           ...
# 74099      1. 큰 수  10000이 몇십, 몇백, 몇천인 수                  여덟 자리 수의 자릿값
# 74167      1. 큰 수                 크기 비교                    큰 수의 크기 비교
# 81690      1. 큰 수                뛰어서 세기                   큰 수를 뛰어서 세기
# 95247  3. 곱셈과 나눗셈                   나눗셈  몫이 한 자리 수인 (세 자리 수)÷(두 자리 수)
# 95248  3. 곱셈과 나눗셈                    곱셈             (세 자리 수)×(두 자리 수)
#
#                                       토픽제목
# 0                               모형 돈 세어 보기
# ...

# %% [markdown]
# ## 1. 데이터 확인하기(카운팅, 유니크 ..)

# %%
value_counts = data['문항코드'].value_counts()
print(value_counts)
# Out:
# 30016616.0    494
# 30016588.0    492
# 30016567.0    492
# 30016575.0    466
# 30016572.0    466
#              ...
# 30028514.0      1
# 30028513.0      1
# 30028512.0      1
# 30028511.0      1
# 30028023.0      1
# Name: 문항코드, Length: 967, dtype: int64

# %%
data['문항코드'].value_counts().sort_values()
# Out:
# 30028023.0      1
# 30093472.0      1
# 30079374.0      1
# 30075605.0      1
# 30051845.0      1
#              ...
# 30016572.0    466
# 30016575.0    466
# 30016567.0    492
# 30016588.0    492
# 30016616.0    494
# Name: 문항코드, Length: 967, dtype: int64

# %%
value_counts = data['대단원제목'].value_counts()
print(value_counts)
# null값을 포함하지 않고 acoount
# Out:
# 2. 각도          21129
# 3. 곱셈과 나눗셈     16783
# 1. 큰 수         16077
# 4. 평면도형의 이동    13426
# 6. 규칙 찾기       13067
# 5. 막대그래프       11199
# 2. 나눗셈            90
# 1. 곱셈             80
# 3. 각도와 삼각형        74
# 3. 원              60
# 4. 분수             60
# 5. 들이와 무게         60
# 6. 자료의 정리         20
# Name: 대단원제목, dtype: int64

# %%
value_counts = data['대단원제목'].value_counts(dropna=False)
print(value_counts)
# 대단원 제목이 null값을 drop하지 않고 account
# Out:
# 2. 각도          21129
# 3. 곱셈과 나눗셈     16783
# 1. 큰 수         16077
# 4. 평면도형의 이동    13426
# 6. 규칙 찾기       13067
# 5. 막대그래프       11199
# NaN             7875
# 2. 나눗셈            90
# 1. 곱셈             80
# 3. 각도와 삼각형        74
# 3. 원              60
# 4. 분수             60
# 5. 들이와 무게         60
# 6. 자료의 정리         20
# Name: 대단원제목, dtype: int64

# %%
data['정오답'].unique()
# Out:
# array(['O', 'X', nan], dtype=object)

# %%
data['정오답'] =  data['정오답'].map({'O': '정답', 'X': '오답'})

# %%
data['정오답']
# Out:
# 0        정답
# 1        정답
# 2        오답
# 3        정답
# 4        정답
#          ..
# 99995    정답
# 99996    정답
# 99997    정답
# 99998    정답
# 99999    정답
# Name: 정오답, Length: 100000, dtype: object

# %% [markdown]
# ## 2. 데이터 생성하기

# %%
data['실제재생시간(분)'] = 0

# %%
data['실제재생시간(분)'] = data['실제재생시간']/60
data['실제재생시간(분)']
# Out:
# 0        0.133333
# 1        0.133333
# 2        0.133333
# 3        0.133333
# 4        0.133333
#            ...
# 99995    1.150000
# 99996    1.116667
# 99997    1.116667
# 99998    1.116667
# 99999    1.116667
# Name: 실제재생시간(분), Length: 100000, dtype: float64

# %% [markdown]
# ## 3. 데이터 집계하기

# %%
contents_time = data['실제재생시간']
print('contents_time max 값:', contents_time.max())
print('contents_time sum 값:', contents_time.min())
print('sum() contents_time:', sum(contents_time))
print('contents_time + 3:\n',(contents_time + 3).head(3) )
# Out:
# contents_time max 값: 176513
# contents_time sum 값: -1
# sum() contents_time: 21980644
# contents_time + 3:
#  0    11
# 1    11
# 2    11
# Name: 실제재생시간, dtype: int64

# %% [markdown]
# ## 4. 데이터 인덱싱 및 필터링 하기

# %%
data.iloc[0,0]
# Out:
# '62fbd7b7-6a32-4da2-b203-acdec95e00b2'

# %%
data.iloc[2,2]
# Out:
# 'T0ME41U43'

# %% [markdown]
# ```python
# data.iloc[:,1]
# ```

# %%
data.iloc[:,1]
# Out:
# 0        T0ME41U43001
# 1        T0ME41U43001
# 2        T0ME41U43001
# 3        T0ME41U43001
# 4        T0ME41U43001
#              ...
# 99995    T0ME41UAB003
# 99996    T0ME41UAB004
# 99997    T0ME41UAB004
# 99998    T0ME41UAB004
# 99999    T0ME41UAB004
# Name: 차시코드, Length: 100000, dtype: object

# %%
data.iloc[:5,0]
# Out:
# 0    62fbd7b7-6a32-4da2-b203-acdec95e00b2
# 1    62fbd7b7-6a32-4da2-b203-acdec95e00b2
# 2    62fbd7b7-6a32-4da2-b203-acdec95e00b2
# 3    62fbd7b7-6a32-4da2-b203-acdec95e00b2
# 4    62fbd7b7-6a32-4da2-b203-acdec95e00b2
# Name: 사용자ID, dtype: object

# %%
data.iloc[:5,0:3]
# Out:
#                                   사용자ID          차시코드       단원코드
# 0  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43
# 1  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43
# 2  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43
# 3  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43
# 4  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43

# %%
data.iloc[:,:]
# Out:
#                                       사용자ID          차시코드       단원코드    단원제목  \
# 0      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 1      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 2      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 3      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 4      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# ...                                     ...           ...        ...     ...
# 99995  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB003  T0ME41UAB   2. 각도
# 99996  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
# 99997  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
# 99998  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
# 99999  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
#
# ...

# %% [markdown]
# #### 조건에 맞는 데이터 찾기

# %%
data[data['사용자ID'] == '62fbd7b7-6a32-4da2-b203-acdec95e00b2']
# Out:
#                                      사용자ID          차시코드       단원코드      단원제목  \
# 0     62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43    1학기 복습
# 1     62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43    1학기 복습
# 2     62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43    1학기 복습
# 3     62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43    1학기 복습
# 4     62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43    1학기 복습
# ...                                    ...           ...        ...       ...
# 1792  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0XE41UAF017  T0XE41UAF  6. 규칙 찾기
# 1793  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0XE41UAF017  T0XE41UAF  6. 규칙 찾기
# 1794  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0XE41UAF017  T0XE41UAF  6. 규칙 찾기
# 1795  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0XE41UAF017  T0XE41UAF  6. 규칙 찾기
# 1796  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0XE41UAF017  T0XE41UAF  6. 규칙 찾기
#
# ...

# %%
data[(data['사용자ID'] == '62fbd7b7-6a32-4da2-b203-acdec95e00b2') & (data['정오답'] == '정답')]
# Out:
#                                      사용자ID          차시코드       단원코드      단원제목  \
# 0     62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43    1학기 복습
# 1     62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43    1학기 복습
# 3     62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43    1학기 복습
# 4     62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43    1학기 복습
# 5     62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43    1학기 복습
# ...                                    ...           ...        ...       ...
# 1666  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41UAF006  T0ME41UAF  6. 규칙 찾기
# 1668  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41UAF006  T0ME41UAF  6. 규칙 찾기
# 1669  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41UAF006  T0ME41UAF  6. 규칙 찾기
# 1670  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41UAF006  T0ME41UAF  6. 규칙 찾기
# 1671  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41UAF006  T0ME41UAF  6. 규칙 찾기
#
# ...

# %% [markdown]
# ## 5. 데이터 정렬, 그룹화 하기

# %% [markdown]
# t 시점에 학생이 푸는 문항의 정오답 예측 --> t-1시점 까지의 데이터를 입력

# %%
data = data.sort_values(by=['학습일'])
data
# Out:
#                                       사용자ID          차시코드       단원코드  \
# 8677   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# 8684   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# 8683   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# 8682   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# 8680   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# ...                                     ...           ...        ...
# 22901  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05061  T0ME41U05
# 22902  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05062  T0ME41U05
# 22903  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05062  T0ME41U05
# 22904  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05062  T0ME41U05
# 22905  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05062  T0ME41U05
#
#            단원제목             강의내용             강의명  학년  학기  시험구분 강의구분 강의타입  \
# ...

# %%
# 내림차순
data = data.sort_values(by=['학습일'], ascending=False)
data
# Out:
#                                       사용자ID          차시코드       단원코드  \
# 22905  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05062  T0ME41U05
# 22904  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05062  T0ME41U05
# 22903  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05062  T0ME41U05
# 22902  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05062  T0ME41U05
# 22901  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05061  T0ME41U05
# ...                                     ...           ...        ...
# 8687   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# 8688   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# 8681   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# 8686   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# 8677   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
#
#            단원제목             강의내용             강의명  학년  학기  시험구분 강의구분 강의타입  \
# ...

# %%
data['대단원제목'].dropna()
# Out:
# 4323    3. 곱셈과 나눗셈
# 4330    3. 곱셈과 나눗셈
# 4329    3. 곱셈과 나눗셈
# 4321    3. 곱셈과 나눗셈
# 4322    3. 곱셈과 나눗셈
#            ...
# 8687        1. 큰 수
# 8688        1. 큰 수
# 8681        1. 큰 수
# 8686        1. 큰 수
# 8677        1. 큰 수
# Name: 대단원제목, Length: 92125, dtype: object

# %%
data = data.sort_values(by=['대단원제목'])
data
# Out:
#                                       사용자ID          차시코드       단원코드  \
# 25988  2e294471-a9fc-4823-98dd-accc8ac9a1d4  T0ME41U37015  T0ME41U37
# 25993  2e294471-a9fc-4823-98dd-accc8ac9a1d4  T0ME41U37015  T0ME41U37
# 25992  2e294471-a9fc-4823-98dd-accc8ac9a1d4  T0ME41U37015  T0ME41U37
# 25994  2e294471-a9fc-4823-98dd-accc8ac9a1d4  T0ME41U37015  T0ME41U37
# 25995  2e294471-a9fc-4823-98dd-accc8ac9a1d4  T0ME41U37015  T0ME41U37
# ...                                     ...           ...        ...
# 17530  8e00d919-cbad-469f-8a59-ac7255fc35a1  T0XE41U01080  T0XE41U01
# 17529  8e00d919-cbad-469f-8a59-ac7255fc35a1  T0XE41U01079  T0XE41U01
# 70046  62349661-6616-4e0b-a975-ace3c8d25332  T0XE41U01084  T0XE41U01
# 10858  a5ba90e7-68fa-4d30-b553-ac59496e86af  T0XE41U01080  T0XE41U01
# 10857  a5ba90e7-68fa-4d30-b553-ac59496e86af  T0XE41U01079  T0XE41U01
#
#              단원제목                    강의내용           강의명  학년  학기  시험구분 강의구분  \
# ...

# %%
data.count()
# Out:
# 사용자ID        100000
# 차시코드         100000
# 단원코드         100000
# 단원제목         100000
# 강의내용         100000
# 강의명          100000
# 학년           100000
# 학기           100000
# 시험구분              0
# 강의구분          99357
# 강의타입         100000
# 동영상재생시간      100000
# 실제재생시간       100000
# 확인문제점수       100000
# 학습일          100000
# 문항번호          92125
# 문항코드          92125
# 사용자입력         92125
# 정오답           92125
# 영역            92125
# 대단원코드         92125
# 대단원제목         92125
# 중단원코드         91821
# 중단원제목         91821
# 소단원코드         90446
# 소단원제목         90446
# 토픽코드          90426
# 토픽제목          90426
# 난이도           92125
# 평가영역          91979
# 실제재생시간(분)    100000
# dtype: int64

# %%
data['확인문제점수'].mean()
# Out:
# 10.74193

# %%
# 같은 대단원 끼리 group화를 하는 것
data_groupby_lunit = data.groupby(by='대단원제목')
print(type(data_groupby_lunit))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
# 사이즈를 보기 위해
data_groupby_lunit.size()
# Out:
# 대단원제목
# 1. 곱셈             80
# 1. 큰 수         16077
# 2. 각도          21129
# 2. 나눗셈            90
# 3. 각도와 삼각형        74
# 3. 곱셈과 나눗셈     16783
# 3. 원              60
# 4. 분수             60
# 4. 평면도형의 이동    13426
# 5. 들이와 무게         60
# 5. 막대그래프       11199
# 6. 규칙 찾기       13067
# 6. 자료의 정리         20
# dtype: int64

# %%
data_groupby_user = data.groupby(by='사용자ID')
data_groupby_user.size()
# Out:
# 사용자ID
# 023b1047-485f-431b-b9f0-ad682229168e    2334
# 03732561-cda6-436d-8457-acc7c16ed570    3032
# 053a6841-0287-461b-ad76-ac368d95a9d1    1354
# 10641145-0be4-48e8-baba-aceec91cdc1b    2708
# 13e6ffa0-6fb7-45a1-8f38-ac6121b58f14    1620
# 17d801a7-7ad1-48bf-ad52-acf0c921773f    2432
# 18265f8a-f6cc-40b8-a070-ad550cd05d58    1687
# 191ebdb4-701a-4f57-b459-ad25fa1515a4    2597
# 1a01d3c2-4393-4c68-9b12-ad9f3cee2c18    3013
# 1ce25bd2-3480-4f91-b326-ad55c117b21f    2473
# 1d7eb435-c3ee-4d10-9cfc-ac5e2cf6ed60    2397
# 1f87e337-aa78-43d8-8a68-acc818faf46e    1338
# 25e953db-e3a3-4bd0-bc1d-ad33c6fce9ae    1685
# 2d7324e5-4773-4f11-b3aa-ad683f2b496a    1896
# 2e294471-a9fc-4823-98dd-accc8ac9a1d4    3573
# 3297b421-1b39-457a-a5d7-acba0b40b642    1805
# 38eda30e-feb5-47a0-9234-ad5572b17060    2051
# 3b91b84e-1e5b-41f8-814d-ad67abd63176    2841
# 41604f8d-5e6d-443c-b822-acf5fe6196a6    2250
# 420d1b3b-3a59-4029-927f-acfb5d73a63a    2487
# 5b397264-58f9-44e4-af91-ad8d7fbe4b1a    1837
# ...

# %%
data['정오답']
# Out:
# 25988     정답
# 25993     정답
# 25992     정답
# 25994     오답
# 25995     오답
#         ...
# 17530    NaN
# 17529    NaN
# 70046    NaN
# 10858    NaN
# 10857    NaN
# Name: 정오답, Length: 100000, dtype: object

# %%
data['정오답'] = data['정오답'].map({'정답': 1, '오답': 0})
data['정오답']
# Out:
# 25988    1.0
# 25993    1.0
# 25992    1.0
# 25994    0.0
# 25995    0.0
#         ...
# 17530    NaN
# 17529    NaN
# 70046    NaN
# 10858    NaN
# 10857    NaN
# Name: 정오답, Length: 100000, dtype: float64

# %%
# 사용자 별로 평균내기
data.groupby('사용자ID')['정오답'].mean() # 사용자별로 데이터를 묶고 정오답을 갖고 평균내기
# Out:
# 사용자ID
# 023b1047-485f-431b-b9f0-ad682229168e    0.897376
# 03732561-cda6-436d-8457-acc7c16ed570    0.858382
# 053a6841-0287-461b-ad76-ac368d95a9d1    0.507950
# 10641145-0be4-48e8-baba-aceec91cdc1b    0.925021
# 13e6ffa0-6fb7-45a1-8f38-ac6121b58f14    0.766199
# 17d801a7-7ad1-48bf-ad52-acf0c921773f    0.465540
# 18265f8a-f6cc-40b8-a070-ad550cd05d58    0.238064
# 191ebdb4-701a-4f57-b459-ad25fa1515a4    0.744133
# 1a01d3c2-4393-4c68-9b12-ad9f3cee2c18    0.501065
# 1ce25bd2-3480-4f91-b326-ad55c117b21f    0.662429
# 1d7eb435-c3ee-4d10-9cfc-ac5e2cf6ed60    0.772009
# 1f87e337-aa78-43d8-8a68-acc818faf46e    0.866310
# 25e953db-e3a3-4bd0-bc1d-ad33c6fce9ae    0.911631
# 2d7324e5-4773-4f11-b3aa-ad683f2b496a    0.674074
# 2e294471-a9fc-4823-98dd-accc8ac9a1d4    0.696206
# 3297b421-1b39-457a-a5d7-acba0b40b642    0.901484
# 38eda30e-feb5-47a0-9234-ad5572b17060    0.771582
# 3b91b84e-1e5b-41f8-814d-ad67abd63176    0.747555
# 41604f8d-5e6d-443c-b822-acf5fe6196a6    0.790777
# ...

# %%
data.isna() # 결측치를 확인하는 함수
# Out:
#        사용자ID   차시코드   단원코드   단원제목   강의내용    강의명     학년     학기  시험구분   강의구분  \
# 25988  False  False  False  False  False  False  False  False  True  False
# 25993  False  False  False  False  False  False  False  False  True  False
# 25992  False  False  False  False  False  False  False  False  True  False
# 25994  False  False  False  False  False  False  False  False  True  False
# 25995  False  False  False  False  False  False  False  False  True  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...   ...    ...
# 17530  False  False  False  False  False  False  False  False  True  False
# 17529  False  False  False  False  False  False  False  False  True  False
# 70046  False  False  False  False  False  False  False  False  True  False
# 10858  False  False  False  False  False  False  False  False  True  False
# 10857  False  False  False  False  False  False  False  False  True  False
#
# ...

# %%
# 리스트로 바꾸기
data['사용자ID'].unique().tolist()
# Out:
# ['2e294471-a9fc-4823-98dd-accc8ac9a1d4',
#  '1f87e337-aa78-43d8-8a68-acc818faf46e',
#  'a5ba90e7-68fa-4d30-b553-ac59496e86af',
#  '1d7eb435-c3ee-4d10-9cfc-ac5e2cf6ed60',
#  'faad5b0a-0e10-493d-9cdd-adba15a9fc51',
#  '10641145-0be4-48e8-baba-aceec91cdc1b',
#  '8a1c68db-edbf-4233-aef0-ad6adf05e8b1',
#  '8e00d919-cbad-469f-8a59-ac7255fc35a1',
#  '03732561-cda6-436d-8457-acc7c16ed570',
#  '7e6090cd-7600-457f-9ca3-acd4fc95cd11',
#  '62349661-6616-4e0b-a975-ace3c8d25332',
#  '25e953db-e3a3-4bd0-bc1d-ad33c6fce9ae',
#  'ba3c1b10-dcc9-4929-85d6-ad5a12f8f58f',
#  '706baa2a-766e-413a-8248-acbef75c8c0c',
#  '1a01d3c2-4393-4c68-9b12-ad9f3cee2c18',
#  'efebb546-d9a8-45d8-9924-acea0baba889',
#  '420d1b3b-3a59-4029-927f-acfb5d73a63a',
#  '81ca38a8-2595-40f2-8a53-ada9aed380f6',
#  '7ad76158-8958-4548-99ac-acfd1426e5a3',
#  '7fd28377-45b8-4a27-9683-ac78e49ddb26',
#  '38eda30e-feb5-47a0-9234-ad5572b17060',
#  '9d497196-cd35-4fea-841b-ad4ce6641c59',
#  '3b91b84e-1e5b-41f8-814d-ad67abd63176',
# ...

# %% [markdown]
# ## 6. 데이터 결측치 및 대체하기

# %% [markdown]
# ```python
# data.tail(3)
# ```

# %% [markdown]
# ```python
# data['난이도'] = data['난이도'].fillna(0)
# ```

# %% [markdown]
# ```python
# data['정오답'] = data['정오답'].fillna(data['정오답'].mean())
# data.tail(3)
# ```

# %%
data['학년'].replace(4, '4학년')
# Out:
# 25988    4학년
# 25993    4학년
# 25992    4학년
# 25994    4학년
# 25995    4학년
#         ...
# 17530    4학년
# 17529    4학년
# 70046    4학년
# 10858    4학년
# 10857    4학년
# Name: 학년, Length: 100000, dtype: object

# %% [markdown]
# ```python
# data['학년'].replace(4, '4학년')
# ```

# %%
data['정오답']
# Out:
# 25988    1.0
# 25993    1.0
# 25992    1.0
# 25994    0.0
# 25995    0.0
#         ...
# 17530    NaN
# 17529    NaN
# 70046    NaN
# 10858    NaN
# 10857    NaN
# Name: 정오답, Length: 100000, dtype: float64

# %%
data['정오답']=data['정오답'].fillna(data['정오답'].mean())

# %%
data['정오답']
# Out:
# 25988    1.000000
# 25993    1.000000
# 25992    1.000000
# 25994    0.000000
# 25995    0.000000
#            ...
# 17530    0.706822
# 17529    0.706822
# 70046    0.706822
# 10858    0.706822
# 10857    0.706822
# Name: 정오답, Length: 100000, dtype: float64

# %% [markdown]
# ## 7. 데이터 가공하기

# %%
def get_square(a):
    return a**2

print('3의 제곱은:',get_square(3))
# Out:
# 3의 제곱은: 9

# %%
lambda_square = lambda x : x ** 2
print('3의 제곱은:',lambda_square(3))
# Out:
# 3의 제곱은: 9

# %%
a=[1,2,3]
squares = map(lambda x : x**2, a)
list(squares)
# Out:
# [1, 4, 9]

# %%
data['사용자ID길이']= data['사용자ID'].apply(lambda x : len(x))
data[['사용자ID길이','사용자ID']].head(3)
# Out:
#        사용자ID길이                                 사용자ID
# 25988       36  2e294471-a9fc-4823-98dd-accc8ac9a1d4
# 25993       36  2e294471-a9fc-4823-98dd-accc8ac9a1d4
# 25992       36  2e294471-a9fc-4823-98dd-accc8ac9a1d4

# %%
data['난이도수준'] = data['난이도'].apply(lambda x : '어려움' if x == 4.0 else '어렵지않음' )
data[['난이도수준','난이도']].drop_duplicates()
# Out:
#        난이도수준  난이도
# 25988  어렵지않음  2.0
# 25995  어렵지않음  3.0
# 66025    어려움  4.0
# 22905  어렵지않음  NaN

# %% [markdown]
# ## 8. 데이터 인코딩, 스케일링

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(data['차시코드'])
labels = encoder.transform(data['차시코드'])
labels
# Out:
# array([139, 139, 139, ..., 630, 626, 625])

# %%
data['차시코드'] = labels
data
# Out:
#                                       사용자ID  차시코드       단원코드        단원제목  \
# 25988  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# 25993  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# 25992  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# 25994  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# 25995  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# ...                                     ...   ...        ...         ...
# 17530  8e00d919-cbad-469f-8a59-ac7255fc35a1   626  T0XE41U01      1. 큰 수
# 17529  8e00d919-cbad-469f-8a59-ac7255fc35a1   625  T0XE41U01      1. 큰 수
# 70046  62349661-6616-4e0b-a975-ace3c8d25332   630  T0XE41U01      1. 큰 수
# 10858  a5ba90e7-68fa-4d30-b553-ac59496e86af   626  T0XE41U01      1. 큰 수
# 10857  a5ba90e7-68fa-4d30-b553-ac59496e86af   625  T0XE41U01      1. 큰 수
#
#                          강의내용           강의명  학년  학기  시험구분 강의구분 강의타입  동영상재생시간  \
# ...

# %%
data['난이도']
pd.get_dummies(data, columns= ['난이도'])
# Out:
#                                       사용자ID  차시코드       단원코드        단원제목  \
# 25988  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# 25993  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# 25992  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# 25994  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# 25995  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# ...                                     ...   ...        ...         ...
# 17530  8e00d919-cbad-469f-8a59-ac7255fc35a1   626  T0XE41U01      1. 큰 수
# 17529  8e00d919-cbad-469f-8a59-ac7255fc35a1   625  T0XE41U01      1. 큰 수
# 70046  62349661-6616-4e0b-a975-ace3c8d25332   630  T0XE41U01      1. 큰 수
# 10858  a5ba90e7-68fa-4d30-b553-ac59496e86af   626  T0XE41U01      1. 큰 수
# 10857  a5ba90e7-68fa-4d30-b553-ac59496e86af   625  T0XE41U01      1. 큰 수
#
#                          강의내용           강의명  학년  학기  시험구분 강의구분 강의타입  동영상재생시간  \
# ...

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = StandardScaler()
scaler.fit(data[data['확인문제점수'] > 0]['확인문제점수'].to_frame())
scaled_data = scaler.transform(data[data['확인문제점수'] > 0]['확인문제점수'].to_frame())
scaled_data
# Out:
# array([[-1.45681317],
#        [-1.45681317],
#        [-1.45681317],
#        ...,
#        [-1.45681317],
#        [-1.45681317],
#        [-1.45681317]])

# %%
scaler = MinMaxScaler()
scaler.fit(data['실제재생시간'].to_frame())
scaled_data = scaler.transform(data['실제재생시간'].to_frame())
scaled_data
# Out:
# array([[2.26610920e-05],
#        [4.85513897e-03],
#        [4.85513897e-03],
#        ...,
#        [5.66527301e-04],
#        [1.35400025e-03],
#        [8.83782589e-04]])

# %% [markdown]
# ## 9. 간단 데이터 시각화

# %%
data.head()
# Out:
#                                       사용자ID  차시코드       단원코드        단원제목  \
# 25988  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# 25993  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# 25992  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# 25994  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
# 25995  2e294471-a9fc-4823-98dd-accc8ac9a1d4   139  T0ME41U37  [복습] 1. 곱셈
#
#                          강의내용           강의명  학년  학기  시험구분 강의구분 강의타입  동영상재생시간  \
# 25988  (몇십몇)×(몇십몇)을 구해 볼까요(2)  수학 1단원 【문제⑦】   4   1   NaN    E  AAA        0
# 25993  (몇십몇)×(몇십몇)을 구해 볼까요(2)  수학 1단원 【문제⑦】   4   1   NaN    E  AAC        0
# 25992  (몇십몇)×(몇십몇)을 구해 볼까요(2)  수학 1단원 【문제⑦】   4   1   NaN    E  AAC        0
# 25994  (몇십몇)×(몇십몇)을 구해 볼까요(2)  수학 1단원 【문제⑦】   4   1   NaN    E  AAC        0
# 25995  (몇십몇)×(몇십몇)을 구해 볼까요(2)  수학 1단원 【문제⑦】   4   1   NaN    E  AAC        0
#
# ...

# %%
import seaborn as sns

sns.distplot(data['차시코드'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='차시코드', ylabel='Density'>
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
# ...

# %%
#sns.distplot(data['난이도'])
sns.histplot(data['난이도'])
# Out:
# <AxesSubplot:xlabel='난이도', ylabel='Count'>
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45212 (\N{HANGUL SYLLABLE NAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 10. 데이터 학습, 테스트 셋 나누기

# %%
X = data[['사용자ID', '강의명', '학습일', '문항코드', '대단원코드', '중단원코드', '소단원코드', '토픽코드']]
Y = data['정오답']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test= train_test_split(X, Y, test_size=0.2, random_state=121)

# %% [markdown]
# ## 연습문제

# %% [markdown]
# 처음부터 시작하기

# %%
data = pd.read_csv('./초등_4학년_수학_차시문항풀이이력.csv', index_col = 0)
data.head()
# Out:
#                                   사용자ID          차시코드       단원코드    단원제목  \
# 0  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 1  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 2  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 3  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 4  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
#
#               강의내용           강의명  학년  학기  시험구분 강의구분 강의타입  동영상재생시간  실제재생시간  \
# 0  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# 1  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# 2  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# 3  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# 4  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
#
#    확인문제점수                  학습일  문항번호        문항코드  \
# ...

# %%
m=data['확인문제점수']==-1
dfm=data[-m]

# %% [markdown]
# ## 1. 학생별 평균점수 구하기 (확인문제점수 = -1 제거)

# %%
pd.DataFrame(dfm.groupby('사용자ID')['확인문제점수'].mean()).head()
# Out:
#                                          확인문제점수
# 사용자ID
# 023b1047-485f-431b-b9f0-ad682229168e  91.006024
# 03732561-cda6-436d-8457-acc7c16ed570  84.564103
# 053a6841-0287-461b-ad76-ac368d95a9d1  51.258741
# 10641145-0be4-48e8-baba-aceec91cdc1b  92.114391
# 13e6ffa0-6fb7-45a1-8f38-ac6121b58f14  76.173010

# %% [markdown]
# ## 2. 학생별 대단원별 평균점수 구하기 (확인문제점수 = -1 제거)

# %%
pd.DataFrame(dfm.groupby(['사용자ID','대단원코드'])['확인문제점수'].mean()).head()
# Out:
#                                                     확인문제점수
# 사용자ID                                대단원코드
# 023b1047-485f-431b-b9f0-ad682229168e 12190030.0  82.000000
#                                      17120995.0  94.847458
#                                      17120996.0  92.000000
#                                      17120997.0  78.500000
#                                      17120998.0  95.190476

# %% [markdown]
# ## 3. 대단원별 평균점수 구하기 (확인문제점수 = -1 제거)

# %%
pd.DataFrame(dfm.groupby('대단원코드')['확인문제점수'].mean()).head()
# Out:
#                확인문제점수
# 대단원코드
# 12160060.0  64.210526
# 12190030.0  74.810811
# 17120995.0  70.929864
# 17120996.0  76.509771
# 17120997.0  56.861876

# %% [markdown]
# ## 4. 평균점수가 높은 순서대로 학생 줄세우기 (확인문제점수 = -1 제거)

# %%
pd.DataFrame(dfm.groupby('사용자ID')['확인문제점수'].mean().sort_values(ascending=False)).head()
# Out:
#                                          확인문제점수
# 사용자ID
# a5ba90e7-68fa-4d30-b553-ac59496e86af  94.404181
# 10641145-0be4-48e8-baba-aceec91cdc1b  92.114391
# 023b1047-485f-431b-b9f0-ad682229168e  91.006024
# 420d1b3b-3a59-4029-927f-acfb5d73a63a  90.516908
# 25e953db-e3a3-4bd0-bc1d-ad33c6fce9ae  89.883792

# %% [markdown]
# ## 5. 데이터 건수가 많은 학생 순서대로 줄세우기

# %%
pd.DataFrame(data['사용자ID'].value_counts()).head()
# Out:
#                                       사용자ID
# 2e294471-a9fc-4823-98dd-accc8ac9a1d4   3573
# 9d497196-cd35-4fea-841b-ad4ce6641c59   3122
# b7c20da8-0d52-4962-b835-ad065d65b6fa   3033
# 03732561-cda6-436d-8457-acc7c16ed570   3032
# 1a01d3c2-4393-4c68-9b12-ad9f3cee2c18   3013

# %% [markdown]
# ## 6. 대단원 '1. 곱셈' 을 풀이한 데이터만 가지고 Train / Test set을 8:2로 나누어 보기

# %%
m2=data['대단원제목']=='1. 곱셈'
df2=data[m2]

# %%
X = df2[['사용자ID', '강의명', '학습일', '문항코드', '대단원코드', '중단원코드', '소단원코드', '토픽코드']]
Y = df2['정오답']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test= train_test_split(X, Y, test_size=0.25, random_state=123)

# %% [markdown]
# ## 7. 자유롭게 더 연습해보기

# %%
import seaborn as sns

sns.distplot(pd.DataFrame(dfm.groupby('대단원코드')['확인문제점수'].mean()))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>
